# %% [markdown]
# Kolegram

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import yfinance as yf

# %%
bist = yf.download('XU100.IS', period='1y', interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
bist['Close'].plot()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# use multiplicative decomposition

result = seasonal_decompose(bist['Close'], model='multiplicative', period=30)
+

# %%
# plot kolegram

fig, (ax1,ax2) = plt.subplots(2,1)
plot_acf(bist['Close'], lags=36, ax=ax1)
plot_pacf(bist['Close'], lags=36, ax=ax2)
